# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches


# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
df1 = pd.read_csv(city_data_to_load)
df2 = pd.read_csv(ride_data_to_load)
df2.head()
# Combine the data into a single dataset
df = df2.merge(df1, how = 'left', on= 'city')
# Display the data table for preview
df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
city_group = df.groupby('city')
total_rides = city_group['city'].count()
average_fare = city_group['fare'].mean()
driver_count_city = city_group['driver_count'].sum()
driver_count_city = pd.to_numeric(driver_count_city, errors='coerce')

# %%
types = city_group['type'].first()

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
colors = {'Urban':'coral', 'Suburban':'lightblue', 'Rural':'yellow'}
plt.scatter(total_rides, average_fare, marker = 'o', c = types.apply(lambda x: colors[x]),\
            alpha = 0.75, s = driver_count_city, edgecolor = 'black')
plt.title('Pyber Ride Sharing Data (2016)')
plt.xlabel('Total Number of Rides Per City')
plt.ylabel('Average Fare ($)')

red_patch = mpatches.Patch(color='coral', label='Urban')
blue_patch = mpatches.Patch(color='lightblue', label='Suburban')
yellow_patch = mpatches.Patch(color='yellow', label='Rural')

patches = [red_patch, blue_patch, yellow_patch]

legend = plt.legend(title = 'City Types', handles=patches,loc='upper right')



plt.grid()
plt.show()
# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure
plt.savefig("Scatter.png")

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
price_group = df.groupby('type')
price_values = price_group['fare'].sum()
# total = float(price_values[0]) + float(price_values[1]) + float(price_values[2])
# price_pct = price_values.apply(lambda x: 100 * x / total)
#price_pct
# Build Pie Chart

labels = ["Rural", "Suburban", "Urban"]

colors = ["yellow", "lightblue", "coral"]

explode = (0, 0, 0.1)

plt.pie(price_values, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title('% of Total Fares by City Type')
# Save Figure
plt.savefig('Pie1.png')

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
type_group = df.groupby('type')
total_rides = type_group['city'].count()

# Build Pie Chart

labels = ["Rural", "Suburban", "Urban"]

colors = ["yellow", "lightblue", "coral"]

explode = (0, 0, 0.1)

plt.pie(total_rides, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title('% of Total Rides by City Type')
plt.show()
# Save Figure
plt.savefig('Pie2.png')

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
type_group = df.groupby('type')
total_rides = type_group['driver_count'].sum()

# Build Pie Chart

labels = ["Rural", "Suburban", "Urban"]

colors = ["yellow", "lightblue", "coral"]

explode = (0, 0, 0.1)

plt.pie(total_rides, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title('% of Total Rides by City Type')
plt.show()
# Save Figure
plt.savefig('Pie3.png')

# %%
# Show Figure
plt.show()
